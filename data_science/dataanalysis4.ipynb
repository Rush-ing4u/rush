# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load The Data

# %%
df = pd.read_excel('Canada.xlsx',sheet_name = 'Canada by Citizenship',skiprows = 20, skipfooter=2)
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %% [markdown]
# ## Pre-Processing OF DATA according to need

# %%
print(df.columns.tolist)
# Out:
# <bound method IndexOpsMixin.tolist of Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')>

# %%
df.rename({
    'OdName': 'country',
    'AreaName':'continent',
    'RegName':'region',
    'DevName': 'country_status'
}, axis= 1, inplace =True)

# %% [markdown]
# check count of values in a categorical column drop if the count is 1

# %%
df.describe(include='object')
# Out:
#               Type    Coverage      country continent        region  \
# count          195         195          195       195           195
# unique           1           2          195         6            22
# top     Immigrants  Foreigners  Afghanistan    Africa  Western Asia
# freq           195         194            1        54            18
#
#             country_status
# count                  195
# unique                   2
# top     Developing regions
# freq                   147

# %%
df['Type'].value_counts()#count number of each unique value in column
# Out:
# Immigrants    195
# Name: Type, dtype: int64

# %% [markdown]
# drop columns which are not required

# %%
cols_to_drop = ['Type','Coverage','AREA','REG','DEV']
df.drop(columns = cols_to_drop,inplace = True ) # columns with no useful data are dropped

# %%
df.set_index('country', inplace=True) # set the country as the index

# %% [markdown]
# adding a total column which is the sum of all the years for particular country

# %%
years = list(range(1980,2014))
df['total'] = df[years].sum(axis=1)
df.head(3)
# Out:
#             continent           region      country_status  1980  1981  1982  \
# country
# Afghanistan      Asia    Southern Asia  Developing regions    16    39    39
# Albania        Europe  Southern Europe   Developed regions     1     0     0
# Algeria        Africa  Northern Africa  Developing regions    80    67    71
#
#              1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  \
# country                              ...
# Afghanistan    47    71   340   496  ...  3436  3009  2652  2111  1746  1758
# Albania         0     0     0     1  ...  1223   856   702   560   716   561
# Algeria        69    63    44    69  ...  3626  4807  3623  4005  5393  4752
#
#              2011  2012  2013  total
# country
# Afghanistan  2203  2635  2004  58639
# Albania       539   620   603  15699
# Algeria      4325  3774  4331  69439
#
# [3 rows x 38 columns]

# %% [markdown]
# making the country status to binary

# %%
def binarize(val):
    if val == 'Developing regions':
        return 0
    else:
        return 1
df['country_status'] = df['country_status'].apply(binarize)

# %%
df.head()
# Out:
#                continent           region  country_status  1980  1981  1982  \
# country
# Afghanistan         Asia    Southern Asia               0    16    39    39
# Albania           Europe  Southern Europe               1     1     0     0
# Algeria           Africa  Northern Africa               0    80    67    71
# American Samoa   Oceania        Polynesia               0     0     1     0
# Andorra           Europe  Southern Europe               1     0     0     0
#
#                 1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  \
# country                                 ...
# Afghanistan       47    71   340   496  ...  3436  3009  2652  2111  1746
# Albania            0     0     0     1  ...  1223   856   702   560   716
# Algeria           69    63    44    69  ...  3626  4807  3623  4005  5393
# American Samoa     0     0     0     0  ...     0     1     0     0     0
# Andorra            0     0     0     2  ...     0     1     1     0     0
#
# ...

# %%
df.sort_values(by='total', ascending=False, inplace=True)
df.head()
# Out:
#                                                    continent  \
# country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 region  \
# country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                     country_status   1980  \
# country
# ...

# %% [markdown]
# ## rename few country names (that is index column)

# %%
print(df.index.to_list())
# Out:
# ['India', 'China', 'United Kingdom of Great Britain and Northern Ireland', 'Philippines', 'Pakistan', 'United States of America', 'Iran (Islamic Republic of)', 'Sri Lanka', 'Republic of Korea', 'Poland', 'Lebanon', 'France', 'Jamaica', 'Viet Nam', 'Romania', 'Haiti', 'Guyana', 'Portugal', 'Egypt', 'Morocco', 'Colombia', 'Iraq', 'Algeria', 'Israel', 'Bangladesh', 'Germany', 'Russian Federation', 'Mexico', 'Afghanistan', 'El Salvador', 'Ukraine', 'Trinidad and Tobago', 'Somalia', 'South Africa', 'Nigeria', 'Jordan', 'Ethiopia', 'Peru', 'Turkey', 'Syrian Arab Republic', 'Brazil', 'Japan', 'Netherlands', 'Ghana', 'Democratic Republic of the Congo', 'Malaysia', 'Australia', 'Bulgaria', 'Italy', 'Bosnia and Herzegovina', 'Chile', 'Venezuela (Bolivarian Republic of)', 'Fiji', 'Cuba', 'Argentina', 'Guatemala', 'Sudan', 'Tunisia', 'Kenya', 'Ireland', 'Hungary', 'Cameroon', 'Albania', 'Mauritius', 'Switzerland', 'Republic of Moldova', 'Singapore', 'Indonesia', 'United Republic of Tanzania', 'G
# ...

# %%
df.rename({
    'United Kingdom of Great Britain and Northern Ireland':'United Kingdom',
    'Venezuela (Bolivarian Republic of)': 'Venezuela',
    'Iran (Islamic Republic of)': 'Iran',
    'United States of America': 'USA',
    'Hong Kong, China (SAR)': 'Hong Kong',
    'Viet Nam': 'Vietnam',
    'The former Yugoslav Republic of Macedonia': 'Macedonia',
    'Bolivia (Plurinational State of)': 'Bolivia',
    "Lao People's Democratic Republic": 'Laos',
    'China, Macao Special Administrative Region': 'Macao',
    'Democratic Republic of the Congo': 'Congo',
}, inplace=True)

# %% [markdown]
# just for this situation ,we have a 40 something columns , and as we can see em , we'll change panda display options to show all columns

# %%
pd.set_option('display.max_rows', None)

# %%
df.head(3)
# Out:
#                continent           region  country_status   1980   1981  \
# country
# India               Asia    Southern Asia               0   8880   8670
# China               Asia     Eastern Asia               0   5123   6682
# United Kingdom    Europe  Northern Europe               1  22045  24796
#
#                  1982   1983   1984  1985  1986  ...   2005   2006   2007  \
# country                                          ...
# India            8147   7338   5704  4211  7150  ...  36210  33848  28742
# China            3308   1863   1527  1816  1960  ...  42584  33518  27642
# United Kingdom  20620  10015  10170  9564  9470  ...   7258   7140   8216
#
#                  2008   2009   2010   2011   2012   2013   total
# country
# India           28261  29456  34235  27509  30933  33087  691904
# China           30037  29622  30391  28502  33024  34129  659962
# United Kingdom   8979   8876   8724   6204   6195   5827  551500
#
# [3 rows x 38 columns]

# %% [markdown]
# ## Change plotting theme

# %%
print(plt.style.available)
plt.style.use('seaborn')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
df.loc['Japan', years].plot(kind='line', figsize=(20,6))
plt.show()

# %% [markdown]
# ## Add pandas styling

# %%
continent_df = df.groupby('continent')[years].sum()

# %%
continent_df.style.background_gradient(cmap='Pastel1_r')
# Out:
# <style type="text/css">
# ...

# %%
continent_df.style.bar(color='black')
# Out:
# <style type="text/css">
# #T_451c0_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, black 9.9%, transparent 9.9%);
# }
# #T_451c0_row0_col1, #T_451c0_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, black 9.7%, transparent 9.7%);
# }
# #T_451c0_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, black 8.9%, transparent 8.9%);
# }
# #T_451c0_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, black 10.8%, transparent 10.8%);
# }
# #T_451c0_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, black 11.1%, transparent 11.1%);
# }
# #T_451c0_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, black 13.2%, transparent 13.2%);
# }
# #T_451c0_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, black 16.0%, transparent 16.0%);
# }
# #T_451c0_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, black 13.8%, transparent 13.8%);
# }
# #T_451c0_row0_col9 {
# ...

# %%
continent_df.style.text_gradient(cmap='winter')
# Out:
# <style type="text/css">
# #T_45282_row0_col0, #T_45282_row0_col2, #T_45282_row4_col10, #T_45282_row4_col29 {
#   color: #000df8;
# }
# #T_45282_row0_col1, #T_45282_row4_col27, #T_45282_row4_col28 {
#   color: #000ff8;
# }
# #T_45282_row0_col3, #T_45282_row0_col4 {
#   color: #0011f6;
# }
# #T_45282_row0_col5 {
#   color: #0013f6;
# }
# #T_45282_row0_col6 {
#   color: #001af2;
# }
# #T_45282_row0_col7, #T_45282_row0_col16 {
#   color: #0023ee;
# }
# #T_45282_row0_col8, #T_45282_row3_col20 {
#   color: #001ef0;
# }
# #T_45282_row0_col9, #T_45282_row0_col18, #T_45282_row0_col19, #T_45282_row0_col20, #T_45282_row3_col18, #T_45282_row3_col23, #T_45282_row4_col7 {
#   color: #0024ed;
# }
# #T_45282_row0_col10, #T_45282_row0_col14, #T_45282_row0_col17 {
#   color: #0020ef;
# }
# #T_45282_row0_col11 {
#   color: #0022ee;
# }
# #T_45282_row0_col12, #T_45282_row3_col27 {
#   color: #002fe8;
# }
# #T_45282_row0_col13, #T_45282_row3_col25 {
#   color: #0025ec;
# }
# ...

# %% [markdown]
# ## Visualization
